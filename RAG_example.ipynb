# %% [markdown]
# # Retrieval Augmented Generation with Amazon Bedrock and Couchbase
#
# Retrieval Augmented Generation (RAG) is a machine learning approach that combines retrieval systems with large language models (LLMs) to generate output that has contextual information that can take advantage of private data and external knowledge sources.
#
# #### Prepare Embeddings
# ![Embeddings](./RAG_pipeline_Couchbase_Bedrock.png)
#
# Before being able to answer the questions, the documents must be processed and a stored in a document store index
# - Create a numerical vector representation of each document using Amazon Bedrock Titan Embeddings model
# - Create an vector index using the corresponding embeddings
#
# #### Ask question
# ![Question](./RAG_runtime_Couchbase_Bedrock.png)
#
# When the vector index is prepared, you are ready to ask the questions and relevant documents will be fetched based on the question being asked. Following steps will be executed.
# - Create an embedding of the input question
# - Compare the question embedding with the embeddings in the index
# - Fetch the (top N) relevant document chunks
# - Add those chunks as part of the context in the prompt
# - Send the prompt to the model under Amazon Bedrock
# - Get the contextual answer based on the documents retrieved

# %% [markdown]
# ## Usecase
# #### Dataset
# In this example, you will use the Couchbase travel sample dataset.

# %% [markdown]
# ## Implementation
# In order to follow the RAG approach, this notebook is using the LangChain framework where it has integrations with different services and tools that allow efficient building of patterns such as RAG. We will be using the following tools:
#
# - **LLM (Large Language Model)**: Anthropic Claude available through Amazon Bedrock
#
# - **Embeddings Model**: Amazon Titan Embeddings available through Amazon Bedrock
#
#   This model will be used to generate a numerical representation of the hotel description and reviews
#
# - **Vector Store**: Couchbase available through LangChain
#
# - **Index**: VectorIndex
#   The index helps to compare the input embedding and the document embeddings to find relevant document.
#
# ### Python 3.10
#
# ⚠️⚠️⚠️ For this lab we need to run the notebook based on a Python 3.10 runtime. ⚠️⚠️⚠️
#
# If you carry out the workshop from your local environment outside of the Amazon SageMaker studio please make sure you are running a Python runtime > 3.10.
#
# ### Note
# It is possible to choose other models available with Bedrock. You can replace the `model_id` as follows to change the model.
#
# `llm = Bedrock(model_id="...")`
#
# ## Sign Up for Capella
# Creating a Capella cluster and setting up a vector database takes a few minutes. Follow the below steps:
# - Go to https://cloud.couchbase.com to create a free tier account.
# - Select your preferred region
# - Configure the cluster access credentials
# - Add an allowed IP address to connect to your cluster
#
# We will use the travel-sample bucket for this demo. The next step is to create the vector index:
# - On the **Databases** page, select the trial cluster where you want to create the vector index.
# - Go to **Data Tools > Search**.
# - Click **Import Search Index**.
# - Upload the **hotel-vector-search.json** file. This file contains the vector index definition.
# - Click **Import** then **Create Index**

# %% [markdown]
# ### Check out this [blog post](https://www.couchbase.com/blog/couchbase-bedrock-rag-applications/) for more details

# %% [markdown]
# # Steps

# %%
# %pip install langchain langchain-couchbase langchain-aws --quiet
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Define helper print function

# %%
from io import StringIO
import sys
import textwrap


def print_ww(*args, width: int = 100, **kwargs):
    """Like print(), but wraps output to `width` characters (default 100)"""
    buffer = StringIO()
    try:
        _stdout = sys.stdout
        sys.stdout = buffer
        print(*args, **kwargs)
        output = buffer.getvalue()
    finally:
        sys.stdout = _stdout
    for line in output.splitlines():
        print("\n".join(textwrap.wrap(line, width=width)))

# %% [markdown]
# Create boto3 Bedrock client. Make sure you have installed the AWS cli if you are not using the Amazon SageMaker studio. Configure the AWS cli with you access credentials

# %%
import boto3
import json
import os
import sys

session = boto3.session.Session()
bedrock_client = session.client('bedrock')

# %% [markdown]
# Create boto3 Bedrock runtime client for embedding and LLM model. Change the AWS region here if needed.

# %%
bedrock_runtime_client = session.client('bedrock-runtime', region_name="us-east-1")
# We will be using the Titan Embeddings Model to generate our Embeddings.
from langchain_aws.embeddings import BedrockEmbeddings
from langchain_aws import BedrockLLM
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# - create the Anthropic Model
llm = BedrockLLM(model_id="anthropic.claude-v2", 
              client=bedrock_runtime_client, 
              model_kwargs={
                  'max_tokens_to_sample': 200
              }, 
              callbacks=[StreamingStdOutCallbackHandler()])

# - create the Titan Embeddings Model
bedrock_embeddings = BedrockEmbeddings(model_id="amazon.titan-embed-g1-text-02",
                                       client=bedrock_runtime_client)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <div>
#         <p><b>Note</b></p>
#         <p> Please add Couchbase Capella connection details to continue. </p>
#     </div>
# </div>

# %%
COUCHBASE_CONNECTION_STRING = "<Enter Couchbase endpoint URL>"

DB_USERNAME = "<Enter Couchbase Database Username>"
DB_PASSWORD = "<Enter Couchbase Database Password>"

from datetime import timedelta
from couchbase.auth import PasswordAuthenticator
from couchbase.cluster import Cluster
from couchbase.options import ClusterOptions

auth = PasswordAuthenticator(DB_USERNAME, DB_PASSWORD)
options = ClusterOptions(auth)
cluster = Cluster(COUCHBASE_CONNECTION_STRING, options)

# Wait until the cluster is ready for use.
cluster.wait_until_ready(timedelta(seconds=5))

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <div>
#         <p><b>Note</b></p>
#         <p> Next block generates vector embedding for the travel-sample data and updates the Couchbase Capella cluster with the vector embeddings. It might take time to run (~ 30 minutes). Please wait.</p>
#     </div>
# </div>

# %%
import couchbase.subdocument as SD
import time

DB_BUCKET = "travel-sample"
DB_SCOPE = "inventory"
DB_COLLECTION = "hotel"
SEARCH_INDEX_NAME = "hotel-vector-search"

bucket = cluster.bucket(DB_BUCKET)
collection = bucket.scope(DB_SCOPE).collection(DB_COLLECTION)

# Query the fields that will be vectorized from the hotel collection
result = cluster.query(
    "SELECT META(h).id as id, h.city as city, h.name as name, h.description as description, ARRAY_COUNT(h.reviews) AS review_count FROM `travel-sample`.inventory.hotel h where vector_embedding is missing"
)

# Not needed. Converting to list only to get the number of rows retrieved
result = list(result)
count = len(result) - 1

for row in result:
    if row["review_count"] > 0:
        data_string = "city: " + str(row["city"])
        data_string = data_string + ". name: " + row["name"]
        data_string = data_string + ". description: " + row["description"]
        data_string = data_string + ". review: "
        try:
            # retrieving the reviews using subdocument mutation
            for i in range(row["review_count"]):
                row_result = collection.lookup_in(
                    row["id"], [SD.get("reviews[" + str(i) + "].content")]
                )
                data_string = data_string + row_result.content_as[str](0)
            
            # Add the data_string that will be vectorized in the same document
            collection.mutate_in(
                row["id"], [SD.upsert("data_string", data_string)]
            )
            
            # Generate the vector embedding and save it in the document
            print(f"Generating vector embedding for doc id: {row['id']}...")
            start = time.time()
            vector_embedding = bedrock_embeddings.embed_query(data_string)
            end = time.time()
            
            print(f"Done in {end - start:.2f} seconds. Now storing the generated embedding in Couchbase")
            start = time.time()
            collection.mutate_in(
                row["id"], [SD.upsert("vector_embedding", vector_embedding)]
            )
            end = time.time()
            print(f"Done in {end - start:.2f} seconds. {count} documents left")
            
        except Exception as e:
            print(f"\033[91mAn error occurred: {e}\033[0m")
            count -= 1
            pass
    else:
        print(f"Skipping doc id: {row['id']}. {count} documents left")
        collection.mutate_in(row["id"], [SD.upsert("data_string", "")])
        collection.mutate_in(row["id"], [SD.upsert("vector_embedding", "")])
        
    count -= 1

print("Done. No more documents")
# Out:
# Generating vector embedding for doc id: hotel_10025...
# Done in 1.21 seconds. Now storing the generated embedding in Couchbase
# Done in 0.28 seconds. 916 documents left
# Skipping doc id: hotel_10026. 915 documents left
# Generating vector embedding for doc id: hotel_10063...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 914 documents left
# Generating vector embedding for doc id: hotel_10064...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 913 documents left
# Generating vector embedding for doc id: hotel_10138...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 912 documents left
# Generating vector embedding for doc id: hotel_10142...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 911 documents left
# Generating vector embedding for doc id: hotel_10158...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 910 documents left
# Generating vector embedding for doc id: hotel_10159...
# Done in 0.48 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 909 documents left
# Generating vector embedding for doc id: hotel_10160...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 908 documents left
# Generating vector embedding for doc id: hotel_10161...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 907 documents left
# Generating vector embedding for doc id: hotel_10180...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 906 documents left
# Generating vector embedding for doc id: hotel_10289...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 905 documents left
# Generating vector embedding for doc id: hotel_10290...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 904 documents left
# Generating vector embedding for doc id: hotel_10291...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 903 documents left
# Generating vector embedding for doc id: hotel_1072...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 902 documents left
# Generating vector embedding for doc id: hotel_10848...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 901 documents left
# Generating vector embedding for doc id: hotel_10849...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 900 documents left
# Generating vector embedding for doc id: hotel_10850...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 899 documents left
# Generating vector embedding for doc id: hotel_10851...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 898 documents left
# Generating vector embedding for doc id: hotel_10904...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 897 documents left
# Skipping doc id: hotel_1097. 896 documents left
# Generating vector embedding for doc id: hotel_11219...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 895 documents left
# Generating vector embedding for doc id: hotel_11315...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 894 documents left
# Generating vector embedding for doc id: hotel_11331...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 893 documents left
# Generating vector embedding for doc id: hotel_11332...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 892 documents left
# Generating vector embedding for doc id: hotel_11376...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 891 documents left
# Generating vector embedding for doc id: hotel_11377...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 890 documents left
# Skipping doc id: hotel_11378. 889 documents left
# Generating vector embedding for doc id: hotel_11485...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 888 documents left
# Generating vector embedding for doc id: hotel_11787...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 887 documents left
# Skipping doc id: hotel_11788. 886 documents left
# Generating vector embedding for doc id: hotel_11789...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 885 documents left
# Generating vector embedding for doc id: hotel_11790...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 884 documents left
# Skipping doc id: hotel_11791. 883 documents left
# Generating vector embedding for doc id: hotel_11795...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 882 documents left
# Generating vector embedding for doc id: hotel_12068...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 881 documents left
# Generating vector embedding for doc id: hotel_12228...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 880 documents left
# Generating vector embedding for doc id: hotel_12229...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 879 documents left
# Generating vector embedding for doc id: hotel_12230...
# Done in 0.46 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 878 documents left
# Generating vector embedding for doc id: hotel_12236...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 877 documents left
# Generating vector embedding for doc id: hotel_12237...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 876 documents left
# Generating vector embedding for doc id: hotel_12238...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 875 documents left
# Generating vector embedding for doc id: hotel_12239...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 874 documents left
# Generating vector embedding for doc id: hotel_12240...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 873 documents left
# Generating vector embedding for doc id: hotel_12241...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 872 documents left
# Generating vector embedding for doc id: hotel_12242...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 871 documents left
# Generating vector embedding for doc id: hotel_12243...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 870 documents left
# Generating vector embedding for doc id: hotel_12337...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 869 documents left
# Generating vector embedding for doc id: hotel_12357...
# Done in 0.50 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 868 documents left
# Generating vector embedding for doc id: hotel_12922...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.20 seconds. 867 documents left
# Generating vector embedding for doc id: hotel_12923...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 866 documents left
# Generating vector embedding for doc id: hotel_12924...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 865 documents left
# Generating vector embedding for doc id: hotel_12925...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 864 documents left
# Generating vector embedding for doc id: hotel_12926...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 863 documents left
# Generating vector embedding for doc id: hotel_12927...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 862 documents left
# Generating vector embedding for doc id: hotel_12928...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 861 documents left
# Generating vector embedding for doc id: hotel_12929...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 860 documents left
# Generating vector embedding for doc id: hotel_12930...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 859 documents left
# Generating vector embedding for doc id: hotel_1357...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 858 documents left
# Generating vector embedding for doc id: hotel_1358...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 857 documents left
# Generating vector embedding for doc id: hotel_1359...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 856 documents left
# Generating vector embedding for doc id: hotel_1360...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 855 documents left
# Generating vector embedding for doc id: hotel_1361...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 854 documents left
# Generating vector embedding for doc id: hotel_1362...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 853 documents left
# Generating vector embedding for doc id: hotel_1363...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 852 documents left
# Generating vector embedding for doc id: hotel_1364...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 851 documents left
# Skipping doc id: hotel_1368. 850 documents left
# Generating vector embedding for doc id: hotel_13701...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 849 documents left
# Generating vector embedding for doc id: hotel_13702...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 848 documents left
# Generating vector embedding for doc id: hotel_14005...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.38 seconds. 847 documents left
# Generating vector embedding for doc id: hotel_14006...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 846 documents left
# Generating vector embedding for doc id: hotel_14225...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 845 documents left
# Generating vector embedding for doc id: hotel_14226...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 844 documents left
# Generating vector embedding for doc id: hotel_1501...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 843 documents left
# Generating vector embedding for doc id: hotel_1506...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 842 documents left
# Generating vector embedding for doc id: hotel_1507...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 841 documents left
# Generating vector embedding for doc id: hotel_15134...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 840 documents left
# Generating vector embedding for doc id: hotel_15135...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 839 documents left
# Generating vector embedding for doc id: hotel_15148...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 838 documents left
# Generating vector embedding for doc id: hotel_15466...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 837 documents left
# Generating vector embedding for doc id: hotel_15539...
# Done in 0.58 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 836 documents left
# Generating vector embedding for doc id: hotel_15558...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 835 documents left
# Generating vector embedding for doc id: hotel_1573...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 834 documents left
# Generating vector embedding for doc id: hotel_15730...
# Done in 0.50 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 833 documents left
# Generating vector embedding for doc id: hotel_15912...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 832 documents left
# Generating vector embedding for doc id: hotel_15913...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 831 documents left
# Generating vector embedding for doc id: hotel_15914...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 830 documents left
# Generating vector embedding for doc id: hotel_15915...
# Done in 0.50 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 829 documents left
# Skipping doc id: hotel_15916. 828 documents left
# Generating vector embedding for doc id: hotel_15917...
# Done in 0.53 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 827 documents left
# Generating vector embedding for doc id: hotel_15918...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 826 documents left
# Generating vector embedding for doc id: hotel_15949...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 825 documents left
# Generating vector embedding for doc id: hotel_15951...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 824 documents left
# Generating vector embedding for doc id: hotel_15955...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 823 documents left
# Generating vector embedding for doc id: hotel_15956...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 822 documents left
# Generating vector embedding for doc id: hotel_15957...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 821 documents left
# Generating vector embedding for doc id: hotel_15965...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 820 documents left
# Generating vector embedding for doc id: hotel_15974...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 819 documents left
# Generating vector embedding for doc id: hotel_15975...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 818 documents left
# Generating vector embedding for doc id: hotel_15976...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 817 documents left
# Generating vector embedding for doc id: hotel_15977...
# Done in 0.50 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 816 documents left
# Generating vector embedding for doc id: hotel_15978...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 815 documents left
# Generating vector embedding for doc id: hotel_16045...
# Done in 0.71 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 814 documents left
# Generating vector embedding for doc id: hotel_16112...
# Done in 0.73 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 813 documents left
# Generating vector embedding for doc id: hotel_16113...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 812 documents left
# Generating vector embedding for doc id: hotel_16114...
# Done in 0.54 seconds. Now storing the generated embedding in Couchbase
# Done in 0.18 seconds. 811 documents left
# Generating vector embedding for doc id: hotel_16167...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 810 documents left
# Generating vector embedding for doc id: hotel_16168...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 809 documents left
# Generating vector embedding for doc id: hotel_16169...
# Done in 0.62 seconds. Now storing the generated embedding in Couchbase
# Done in 0.20 seconds. 808 documents left
# Generating vector embedding for doc id: hotel_16170...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 807 documents left
# Generating vector embedding for doc id: hotel_16171...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 806 documents left
# Generating vector embedding for doc id: hotel_16172...
# Done in 0.46 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 805 documents left
# Generating vector embedding for doc id: hotel_16173...
# Done in 0.54 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 804 documents left
# Generating vector embedding for doc id: hotel_16174...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 803 documents left
# Generating vector embedding for doc id: hotel_16175...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 802 documents left
# Generating vector embedding for doc id: hotel_16176...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 801 documents left
# Generating vector embedding for doc id: hotel_16177...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 800 documents left
# Generating vector embedding for doc id: hotel_16178...
# Done in 0.46 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 799 documents left
# Generating vector embedding for doc id: hotel_16179...
# Done in 0.51 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 798 documents left
# Generating vector embedding for doc id: hotel_16180...
# Done in 0.50 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 797 documents left
# Generating vector embedding for doc id: hotel_16235...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 796 documents left
# Generating vector embedding for doc id: hotel_16236...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 795 documents left
# Generating vector embedding for doc id: hotel_16237...
# Done in 0.63 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 794 documents left
# Skipping doc id: hotel_16238. 793 documents left
# Generating vector embedding for doc id: hotel_16239...
# Done in 0.49 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 792 documents left
# Generating vector embedding for doc id: hotel_16258...
# Done in 0.45 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 791 documents left
# Generating vector embedding for doc id: hotel_16262...
# Done in 0.45 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 790 documents left
# Generating vector embedding for doc id: hotel_1627...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 789 documents left
# Generating vector embedding for doc id: hotel_16345...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 788 documents left
# Generating vector embedding for doc id: hotel_16346...
# Done in 0.55 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 787 documents left
# Skipping doc id: hotel_16347. 786 documents left
# Generating vector embedding for doc id: hotel_16348...
# Done in 0.49 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 785 documents left
# Generating vector embedding for doc id: hotel_16349...
# Done in 0.46 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 784 documents left
# Generating vector embedding for doc id: hotel_16350...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 783 documents left
# Generating vector embedding for doc id: hotel_16351...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 782 documents left
# Generating vector embedding for doc id: hotel_16435...
# Done in 0.52 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 781 documents left
# Generating vector embedding for doc id: hotel_16436...
# Done in 0.55 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 780 documents left
# Generating vector embedding for doc id: hotel_16437...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 779 documents left
# Generating vector embedding for doc id: hotel_16438...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 778 documents left
# Generating vector embedding for doc id: hotel_16439...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 777 documents left
# Generating vector embedding for doc id: hotel_16440...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 776 documents left
# Generating vector embedding for doc id: hotel_16441...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 775 documents left
# Generating vector embedding for doc id: hotel_16442...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 774 documents left
# Generating vector embedding for doc id: hotel_16443...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 773 documents left
# Generating vector embedding for doc id: hotel_16444...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 772 documents left
# Generating vector embedding for doc id: hotel_16445...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 771 documents left
# Generating vector embedding for doc id: hotel_16446...
# Done in 0.33 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 770 documents left
# Generating vector embedding for doc id: hotel_16447...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 769 documents left
# Generating vector embedding for doc id: hotel_16448...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 768 documents left
# Generating vector embedding for doc id: hotel_16449...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 767 documents left
# Generating vector embedding for doc id: hotel_16450...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 766 documents left
# Generating vector embedding for doc id: hotel_16451...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 765 documents left
# Generating vector embedding for doc id: hotel_16452...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 764 documents left
# Skipping doc id: hotel_16453. 763 documents left
# Generating vector embedding for doc id: hotel_16454...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 762 documents left
# Skipping doc id: hotel_16455. 761 documents left
# Generating vector embedding for doc id: hotel_16456...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 760 documents left
# Generating vector embedding for doc id: hotel_16457...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 759 documents left
# Generating vector embedding for doc id: hotel_16458...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 758 documents left
# Generating vector embedding for doc id: hotel_16459...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 757 documents left
# Generating vector embedding for doc id: hotel_16460...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 756 documents left
# Generating vector embedding for doc id: hotel_16461...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 755 documents left
# Generating vector embedding for doc id: hotel_16521...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 754 documents left
# Generating vector embedding for doc id: hotel_16522...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 753 documents left
# Generating vector embedding for doc id: hotel_16523...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 752 documents left
# Generating vector embedding for doc id: hotel_16524...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 751 documents left
# Generating vector embedding for doc id: hotel_16525...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 750 documents left
# Generating vector embedding for doc id: hotel_16526...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 749 documents left
# Generating vector embedding for doc id: hotel_16527...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 748 documents left
# Generating vector embedding for doc id: hotel_16528...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 747 documents left
# Generating vector embedding for doc id: hotel_16529...
# Done in 0.49 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 746 documents left
# Generating vector embedding for doc id: hotel_16530...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 745 documents left
# Generating vector embedding for doc id: hotel_16630...
# Done in 0.61 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 744 documents left
# Generating vector embedding for doc id: hotel_16631...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 743 documents left
# Generating vector embedding for doc id: hotel_16632...
# Done in 0.33 seconds. Now storing the generated embedding in Couchbase
# Done in 0.20 seconds. 742 documents left
# Generating vector embedding for doc id: hotel_16633...
# Done in 0.32 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 741 documents left
# Generating vector embedding for doc id: hotel_16634...
# Done in 0.46 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 740 documents left
# Generating vector embedding for doc id: hotel_16635...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 739 documents left
# Skipping doc id: hotel_16636. 738 documents left
# Generating vector embedding for doc id: hotel_16637...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 737 documents left
# Generating vector embedding for doc id: hotel_16638...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 736 documents left
# Generating vector embedding for doc id: hotel_16639...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 735 documents left
# Generating vector embedding for doc id: hotel_16640...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 734 documents left
# Generating vector embedding for doc id: hotel_16648...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 733 documents left
# Generating vector embedding for doc id: hotel_16686...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.20 seconds. 732 documents left
# Generating vector embedding for doc id: hotel_16687...
# Done in 0.46 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 731 documents left
# Generating vector embedding for doc id: hotel_16708...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 730 documents left
# Generating vector embedding for doc id: hotel_16709...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 729 documents left
# Generating vector embedding for doc id: hotel_16710...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 728 documents left
# Generating vector embedding for doc id: hotel_17308...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 727 documents left
# Skipping doc id: hotel_17309. 726 documents left
# Generating vector embedding for doc id: hotel_17310...
# Done in 0.49 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 725 documents left
# Skipping doc id: hotel_17311. 724 documents left
# Generating vector embedding for doc id: hotel_17312...
# Done in 0.60 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 723 documents left
# Generating vector embedding for doc id: hotel_17313...
# Done in 0.68 seconds. Now storing the generated embedding in Couchbase
# Done in 0.20 seconds. 722 documents left
# Generating vector embedding for doc id: hotel_17413...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 721 documents left
# Generating vector embedding for doc id: hotel_17414...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 720 documents left
# Generating vector embedding for doc id: hotel_17415...
# Done in 0.32 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 719 documents left
# Generating vector embedding for doc id: hotel_17416...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 718 documents left
# Generating vector embedding for doc id: hotel_17595...
# Done in 0.49 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 717 documents left
# Generating vector embedding for doc id: hotel_17596...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 716 documents left
# Generating vector embedding for doc id: hotel_17597...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 715 documents left
# Generating vector embedding for doc id: hotel_17598...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 714 documents left
# Generating vector embedding for doc id: hotel_17599...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 713 documents left
# Skipping doc id: hotel_17600. 712 documents left
# Generating vector embedding for doc id: hotel_17932...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 711 documents left
# Generating vector embedding for doc id: hotel_18819...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 710 documents left
# Generating vector embedding for doc id: hotel_18843...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 709 documents left
# Generating vector embedding for doc id: hotel_18844...
# Done in 0.45 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 708 documents left
# Generating vector embedding for doc id: hotel_18845...
# Done in 0.32 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 707 documents left
# Generating vector embedding for doc id: hotel_19198...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 706 documents left
# Generating vector embedding for doc id: hotel_19199...
# Done in 0.33 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 705 documents left
# Generating vector embedding for doc id: hotel_19323...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 704 documents left
# Generating vector embedding for doc id: hotel_19324...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 703 documents left
# Skipping doc id: hotel_19325. 702 documents left
# Generating vector embedding for doc id: hotel_19326...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 701 documents left
# Generating vector embedding for doc id: hotel_20122...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 700 documents left
# Generating vector embedding for doc id: hotel_20123...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 699 documents left
# Generating vector embedding for doc id: hotel_20124...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 698 documents left
# Generating vector embedding for doc id: hotel_20147...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 697 documents left
# Generating vector embedding for doc id: hotel_20355...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 696 documents left
# Generating vector embedding for doc id: hotel_20356...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 695 documents left
# Generating vector embedding for doc id: hotel_20357...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 694 documents left
# Skipping doc id: hotel_20419. 693 documents left
# Generating vector embedding for doc id: hotel_20420...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 692 documents left
# Generating vector embedding for doc id: hotel_20421...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 691 documents left
# Generating vector embedding for doc id: hotel_20422...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 690 documents left
# Generating vector embedding for doc id: hotel_20423...
# Done in 0.45 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 689 documents left
# Skipping doc id: hotel_20424. 688 documents left
# Generating vector embedding for doc id: hotel_20425...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 687 documents left
# Generating vector embedding for doc id: hotel_20737...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 686 documents left
# Generating vector embedding for doc id: hotel_20738...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 685 documents left
# Generating vector embedding for doc id: hotel_20739...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 684 documents left
# Generating vector embedding for doc id: hotel_20740...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 683 documents left
# Generating vector embedding for doc id: hotel_20794...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 682 documents left
# Generating vector embedding for doc id: hotel_20955...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 681 documents left
# Generating vector embedding for doc id: hotel_20956...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 680 documents left
# Skipping doc id: hotel_20957. 679 documents left
# Skipping doc id: hotel_20958. 678 documents left
# Generating vector embedding for doc id: hotel_20959...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 677 documents left
# Generating vector embedding for doc id: hotel_21030...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 676 documents left
# Generating vector embedding for doc id: hotel_21031...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 675 documents left
# Generating vector embedding for doc id: hotel_21032...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 674 documents left
# Generating vector embedding for doc id: hotel_21036...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 673 documents left
# Generating vector embedding for doc id: hotel_21037...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 672 documents left
# Skipping doc id: hotel_21038. 671 documents left
# Generating vector embedding for doc id: hotel_21039...
# Done in 0.72 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 670 documents left
# Generating vector embedding for doc id: hotel_21040...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 669 documents left
# Generating vector embedding for doc id: hotel_21042...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 668 documents left
# Skipping doc id: hotel_21043. 667 documents left
# Generating vector embedding for doc id: hotel_21044...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 666 documents left
# Skipping doc id: hotel_21045. 665 documents left
# Generating vector embedding for doc id: hotel_21046...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 664 documents left
# Generating vector embedding for doc id: hotel_21047...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 663 documents left
# Generating vector embedding for doc id: hotel_21049...
# Done in 0.32 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 662 documents left
# Generating vector embedding for doc id: hotel_21050...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 661 documents left
# Generating vector embedding for doc id: hotel_21052...
# Done in 0.45 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 660 documents left
# Generating vector embedding for doc id: hotel_21181...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 659 documents left
# Skipping doc id: hotel_21241. 658 documents left
# Generating vector embedding for doc id: hotel_21242...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 657 documents left
# Generating vector embedding for doc id: hotel_21243...
# Done in 0.49 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 656 documents left
# Generating vector embedding for doc id: hotel_21244...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 655 documents left
# Generating vector embedding for doc id: hotel_21551...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 654 documents left
# Generating vector embedding for doc id: hotel_21552...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 653 documents left
# Generating vector embedding for doc id: hotel_21608...
# Done in 0.32 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 652 documents left
# Generating vector embedding for doc id: hotel_21649...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 651 documents left
# Skipping doc id: hotel_21650. 650 documents left
# Generating vector embedding for doc id: hotel_21651...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 649 documents left
# Generating vector embedding for doc id: hotel_21652...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 648 documents left
# Generating vector embedding for doc id: hotel_21653...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.20 seconds. 647 documents left
# Generating vector embedding for doc id: hotel_21654...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 646 documents left
# Generating vector embedding for doc id: hotel_21655...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 645 documents left
# Generating vector embedding for doc id: hotel_21656...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 644 documents left
# Generating vector embedding for doc id: hotel_21657...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 643 documents left
# Skipping doc id: hotel_21661. 642 documents left
# Generating vector embedding for doc id: hotel_21662...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 641 documents left
# Generating vector embedding for doc id: hotel_21663...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 640 documents left
# Generating vector embedding for doc id: hotel_21664...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 639 documents left
# Generating vector embedding for doc id: hotel_21665...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 638 documents left
# Skipping doc id: hotel_21666. 637 documents left
# Generating vector embedding for doc id: hotel_21668...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 636 documents left
# Generating vector embedding for doc id: hotel_21669...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 635 documents left
# Generating vector embedding for doc id: hotel_21670...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 634 documents left
# Generating vector embedding for doc id: hotel_21671...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 633 documents left
# Generating vector embedding for doc id: hotel_21672...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 632 documents left
# Generating vector embedding for doc id: hotel_21673...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 631 documents left
# Generating vector embedding for doc id: hotel_21674...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 630 documents left
# Generating vector embedding for doc id: hotel_21675...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 629 documents left
# Skipping doc id: hotel_21676. 628 documents left
# Generating vector embedding for doc id: hotel_21677...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 627 documents left
# Generating vector embedding for doc id: hotel_21679...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 626 documents left
# Generating vector embedding for doc id: hotel_21680...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 625 documents left
# Generating vector embedding for doc id: hotel_21720...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 624 documents left
# Generating vector embedding for doc id: hotel_21721...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 623 documents left
# Generating vector embedding for doc id: hotel_21722...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 622 documents left
# Generating vector embedding for doc id: hotel_21723...
# Done in 0.68 seconds. Now storing the generated embedding in Couchbase
# Done in 0.20 seconds. 621 documents left
# Generating vector embedding for doc id: hotel_21724...
# Done in 0.33 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 620 documents left
# Generating vector embedding for doc id: hotel_21725...
# Done in 0.58 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 619 documents left
# Generating vector embedding for doc id: hotel_21726...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 618 documents left
# Generating vector embedding for doc id: hotel_21727...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 617 documents left
# Generating vector embedding for doc id: hotel_21728...
# Done in 0.59 seconds. Now storing the generated embedding in Couchbase
# Done in 0.20 seconds. 616 documents left
# Generating vector embedding for doc id: hotel_21729...
# Done in 0.55 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 615 documents left
# Skipping doc id: hotel_21730. 614 documents left
# Generating vector embedding for doc id: hotel_21731...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 613 documents left
# Generating vector embedding for doc id: hotel_21732...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 612 documents left
# Generating vector embedding for doc id: hotel_21733...
# Done in 0.55 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 611 documents left
# Generating vector embedding for doc id: hotel_21734...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 610 documents left
# Generating vector embedding for doc id: hotel_21735...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 609 documents left
# ...
# Done in 0.14 seconds. 103 documents left
# Skipping doc id: hotel_5082. 102 documents left
# Generating vector embedding for doc id: hotel_5097...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 101 documents left
# Skipping doc id: hotel_5098. 100 documents left
# Generating vector embedding for doc id: hotel_5110...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 99 documents left
# Generating vector embedding for doc id: hotel_5111...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 98 documents left
# Generating vector embedding for doc id: hotel_5112...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 97 documents left
# Skipping doc id: hotel_5113. 96 documents left
# Generating vector embedding for doc id: hotel_5114...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 95 documents left
# Generating vector embedding for doc id: hotel_5119...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 94 documents left
# Generating vector embedding for doc id: hotel_5120...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 93 documents left
# Generating vector embedding for doc id: hotel_5192...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 92 documents left
# Generating vector embedding for doc id: hotel_5193...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 91 documents left
# Generating vector embedding for doc id: hotel_5332...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 90 documents left
# Generating vector embedding for doc id: hotel_5333...
# Done in 0.46 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 89 documents left
# Generating vector embedding for doc id: hotel_5334...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 88 documents left
# Generating vector embedding for doc id: hotel_5335...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 87 documents left
# Generating vector embedding for doc id: hotel_5336...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 86 documents left
# Generating vector embedding for doc id: hotel_5337...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 85 documents left
# Generating vector embedding for doc id: hotel_5338...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 84 documents left
# Skipping doc id: hotel_5580. 83 documents left
# Generating vector embedding for doc id: hotel_5839...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 82 documents left
# Generating vector embedding for doc id: hotel_5840...
# Done in 0.33 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 81 documents left
# Generating vector embedding for doc id: hotel_5841...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 80 documents left
# Generating vector embedding for doc id: hotel_5842...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 79 documents left
# Generating vector embedding for doc id: hotel_5843...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 78 documents left
# Generating vector embedding for doc id: hotel_5844...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 77 documents left
# Generating vector embedding for doc id: hotel_5845...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 76 documents left
# Generating vector embedding for doc id: hotel_5846...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 75 documents left
# Generating vector embedding for doc id: hotel_5847...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 74 documents left
# Generating vector embedding for doc id: hotel_5848...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 73 documents left
# Generating vector embedding for doc id: hotel_593...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 72 documents left
# Generating vector embedding for doc id: hotel_594...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 71 documents left
# Generating vector embedding for doc id: hotel_595...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 70 documents left
# Skipping doc id: hotel_596. 69 documents left
# Generating vector embedding for doc id: hotel_597...
# Done in 0.44 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 68 documents left
# Generating vector embedding for doc id: hotel_6076...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 67 documents left
# Generating vector embedding for doc id: hotel_6169...
# Done in 0.49 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 66 documents left
# Generating vector embedding for doc id: hotel_635...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 65 documents left
# Generating vector embedding for doc id: hotel_6351...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 64 documents left
# Skipping doc id: hotel_64. 63 documents left
# Generating vector embedding for doc id: hotel_65...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 62 documents left
# Generating vector embedding for doc id: hotel_6907...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 61 documents left
# Generating vector embedding for doc id: hotel_6931...
# Done in 0.31 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 60 documents left
# Generating vector embedding for doc id: hotel_7000...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 59 documents left
# Generating vector embedding for doc id: hotel_7001...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 58 documents left
# Generating vector embedding for doc id: hotel_7007...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 57 documents left
# Generating vector embedding for doc id: hotel_7008...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 56 documents left
# Generating vector embedding for doc id: hotel_7060...
# Done in 0.43 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 55 documents left
# Generating vector embedding for doc id: hotel_7061...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 54 documents left
# Generating vector embedding for doc id: hotel_7062...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 53 documents left
# Generating vector embedding for doc id: hotel_7384...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 52 documents left
# Generating vector embedding for doc id: hotel_7385...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 51 documents left
# Generating vector embedding for doc id: hotel_7386...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 50 documents left
# Generating vector embedding for doc id: hotel_7387...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 49 documents left
# Generating vector embedding for doc id: hotel_7388...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 48 documents left
# Generating vector embedding for doc id: hotel_7389...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 47 documents left
# Generating vector embedding for doc id: hotel_7390...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 46 documents left
# Generating vector embedding for doc id: hotel_7391...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 45 documents left
# Generating vector embedding for doc id: hotel_7392...
# Done in 0.60 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 44 documents left
# Generating vector embedding for doc id: hotel_7393...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 43 documents left
# Generating vector embedding for doc id: hotel_7394...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 42 documents left
# Generating vector embedding for doc id: hotel_7395...
# Done in 0.45 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 41 documents left
# Generating vector embedding for doc id: hotel_7396...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 40 documents left
# Generating vector embedding for doc id: hotel_7624...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 39 documents left
# Generating vector embedding for doc id: hotel_7766...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 38 documents left
# Generating vector embedding for doc id: hotel_7767...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 37 documents left
# Generating vector embedding for doc id: hotel_7768...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 36 documents left
# Generating vector embedding for doc id: hotel_7769...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 35 documents left
# Generating vector embedding for doc id: hotel_7770...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 34 documents left
# Skipping doc id: hotel_7771. 33 documents left
# Generating vector embedding for doc id: hotel_7780...
# Done in 0.32 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 32 documents left
# Generating vector embedding for doc id: hotel_7781...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 31 documents left
# Generating vector embedding for doc id: hotel_7782...
# Done in 0.35 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 30 documents left
# Generating vector embedding for doc id: hotel_8340...
# Done in 0.33 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 29 documents left
# Skipping doc id: hotel_8349. 28 documents left
# Generating vector embedding for doc id: hotel_8495...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 27 documents left
# Generating vector embedding for doc id: hotel_8551...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 26 documents left
# Generating vector embedding for doc id: hotel_8576...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 25 documents left
# Generating vector embedding for doc id: hotel_8661...
# Done in 0.34 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 24 documents left
# Generating vector embedding for doc id: hotel_8662...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 23 documents left
# Skipping doc id: hotel_8663. 22 documents left
# Generating vector embedding for doc id: hotel_8664...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 21 documents left
# Generating vector embedding for doc id: hotel_8685...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 20 documents left
# Generating vector embedding for doc id: hotel_8709...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 19 documents left
# Generating vector embedding for doc id: hotel_8710...
# Done in 0.32 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 18 documents left
# Generating vector embedding for doc id: hotel_8711...
# Done in 0.38 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 17 documents left
# Generating vector embedding for doc id: hotel_8712...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 16 documents left
# Generating vector embedding for doc id: hotel_8962...
# Done in 0.41 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 15 documents left
# Generating vector embedding for doc id: hotel_8966...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 14 documents left
# Generating vector embedding for doc id: hotel_9062...
# Done in 0.32 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 13 documents left
# Generating vector embedding for doc id: hotel_9084...
# Done in 0.48 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 12 documents left
# Generating vector embedding for doc id: hotel_9085...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 11 documents left
# Generating vector embedding for doc id: hotel_9086...
# Done in 0.36 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 10 documents left
# Generating vector embedding for doc id: hotel_9154...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 9 documents left
# Generating vector embedding for doc id: hotel_9292...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 8 documents left
# Generating vector embedding for doc id: hotel_9293...
# Done in 0.37 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 7 documents left
# Generating vector embedding for doc id: hotel_9294...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 6 documents left
# Generating vector embedding for doc id: hotel_9335...
# Done in 0.40 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 5 documents left
# Generating vector embedding for doc id: hotel_9336...
# Done in 0.47 seconds. Now storing the generated embedding in Couchbase
# Done in 0.15 seconds. 4 documents left
# Generating vector embedding for doc id: hotel_9343...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 3 documents left
# Generating vector embedding for doc id: hotel_9723...
# Done in 0.42 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 2 documents left
# Generating vector embedding for doc id: hotel_9724...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 1 documents left
# Generating vector embedding for doc id: hotel_9905...
# Done in 0.39 seconds. Now storing the generated embedding in Couchbase
# Done in 0.14 seconds. 0 documents left
# Done. No more documents

# %% [markdown]
# Define Couchbase as vector store.

# %%
from langchain_couchbase import CouchbaseSearchVectorStore
vectorstore_cb = CouchbaseSearchVectorStore(
    embedding=bedrock_embeddings,
    cluster=cluster,
    bucket_name=DB_BUCKET,
    scope_name=DB_SCOPE,
    collection_name=DB_COLLECTION,
    index_name=SEARCH_INDEX_NAME,
    text_key="data_string",
    embedding_key="vector_embedding",
    
)

# %% [markdown]
# ### Similarity / Semantic Search
# Now we can do similarity/semantic search on the vector store in Couchbase. The below cell will retrieve the top 5 results for the given query.

# %%
query = "which hotel has best reviews in the city with golden gate?"

results = vectorstore_cb.similarity_search(query, fields=["name", "city", "free_breakfast"], k=5)
for res in results:
    print_ww(res.metadata)
# Out:
# {'city': 'San Francisco', 'free_breakfast': False, 'name': 'Hotel Diva'}
# {'city': 'San Francisco', 'free_breakfast': True, 'name': 'The Orchard Garden Hotel'}
# {'city': 'San Francisco', 'free_breakfast': True, 'name': 'The Inn San Francisco'}
# {'city': 'San Francisco', 'free_breakfast': True, 'name': 'Ritz-Carlton San Francisco'}
# {'city': 'San Francisco', 'free_breakfast': True, 'name': 'Hotel Carlton'}

# %% [markdown]
# ### Using Retrieval Rugmented Generation
#
# The below implementation of RAG will do the following:
# - Prepare a prompt which goes as input to the LLM running in AWS Bedrock
# - Retrieve documents related to the question
# - Present an answer in a human friendly manner

# %%
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

prompt_template = """

Human: Use the following pieces of context to provide an answer to the question at the end with reason. If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}

Assistant:"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore_cb.as_retriever(
        search_type="similarity", search_kwargs={"k": 10}
    ),
    return_source_documents=True,
    chain_type_kwargs={"prompt": PROMPT},
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %%
query = "which hotel has negative reviews in San Francisco?"
result = qa.invoke({"query": query})

print(f'Query: {result["query"]}\n')
print_ww(f'Result: {result["result"]}\n')
print(f'\nContext Documents: ')
for srcdoc in result["source_documents"]:
      print_ww(f'{srcdoc.metadata}\n')
# Out:
# Query: which hotel has negative reviews in San Francisco?
#
# Result:  Based on the reviews provided, these hotels in San Francisco seem to have some negative
# reviews:
#
# - The Orchard Garden Hotel: One review mentions issues with bed bugs.
#
# - Hotel Carlton: One review mentions the hotel was overbooked, the room smelled of cigarette smoke,
# and the staff was unhelpful.
#
# - Chancellor Hotel: One review describes this hotel negatively, mentioning issues with noise from
# the street.
#
# The other hotels (The Inn San Francisco, Ritz-Carlton San Francisco, Courtyard San Francisco
# Downtown, Marriott Marquis, Stanford Court Hotel, Hotel Diva, and Hotel Griffon) do not have clearly
# negative reviews based on the information provided. The Orchard Garden Hotel, Hotel Carlton, and
# Chancellor Hotel seem to have the most negative feedback.
#
#
# Context Documents:
# {'checkin': '2PM', 'checkout': 'Noon', 'city': 'San Francisco', 'country': 'United States',
# 'free_breakfast': True, 'free_internet': True, 'free_parking': False, 'name': 'The Inn San
# Francisco', 'pets_ok': True, 'phone': '+1 415 641-0188', 'price': '$120+'}
#
# {'checkin': '3PM', 'checkout': '12PM', 'city': 'San Francisco', 'country': 'United States',
# 'free_breakfast': True, 'free_internet': True, 'free_parking': False, 'name': 'Ritz-Carlton San
# Francisco', 'pets_ok': True, 'phone': '+1 415 296-7465', 'price': '$449-$500'}
#
# {'checkin': '3PM', 'checkout': '12PM', 'city': 'San Francisco', 'country': 'United States',
# 'free_breakfast': True, 'free_internet': True, 'free_parking': True, 'name': 'The Orchard Garden
# Hotel', 'pets_ok': True, 'phone': '+1 415 399-9807', 'price': '$200-$309'}
#
# {'checkin': '3PM', 'checkout': 'noon', 'city': 'San Francisco', 'country': 'United States',
# 'free_breakfast': False, 'free_internet': True, 'free_parking': True, 'name': 'Hotel Diva',
# 'pets_ok': False, 'phone': '+1 415 885-0200', 'price': '$149-$226'}
#
# {'city': 'San Francisco', 'country': 'United States', 'free_breakfast': True, 'free_internet': True,
# 'free_parking': True, 'name': 'Hotel Carlton', 'pets_ok': True, 'phone': '+1 415 673-0242'}
#
# {'city': 'San Francisco', 'country': 'United States', 'free_breakfast': True, 'free_internet':
# False, 'free_parking': False, 'name': 'Stanford Court Hotel', 'pets_ok': True, 'phone': '+1 415
# 989-3500'}
#
# {'city': 'San Francisco', 'country': 'United States', 'free_breakfast': True, 'free_internet': True,
# 'free_parking': True, 'name': 'Courtyard San Francisco Downtown', 'pets_ok': False, 'phone': '+1 415
# 947-0700', 'price': '$200–$250'}
#
# {'city': 'San Francisco', 'country': 'United States', 'free_breakfast': True, 'free_internet': True,
# 'free_parking': False, 'name': 'Marriott Marquis', 'pets_ok': True, 'phone': '+1 415 896-1600'}
#
# {'city': 'San Francisco', 'country': 'United States', 'free_breakfast': True, 'free_internet':
# False, 'free_parking': False, 'name': 'Chancellor Hotel', 'pets_ok': True, 'phone': '+1 415
# 362-2004', 'price': '$90–$200'}
#
# {'city': 'San Francisco', 'country': 'United States', 'free_breakfast': False, 'free_internet':
# True, 'free_parking': False, 'name': 'Hotel Griffon', 'pets_ok': False, 'phone': '+1 415 495-2100'}

# %% [markdown]
# ## Conclusion
# Congratulations on completing this module on retrieval augmented generation! This is an important technique that combines the power of large language models with the precision of retrieval methods. By augmenting generation with relevant retrieved examples, the responses we recieved become more coherent, consistent and grounded. I'm sure the knowledge you've gained will be very useful for building creative and engaging language generation systems. Well done!
#
# # Thank You
